# %%
from lxml import html
import requests
import datetime
from pprint import pprint

# %%
header = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:69.0) Gecko/20100101 Firefox/69.0'}

response = requests.get('https://yandex.ru/news',
                            headers=header)
dom = html.fromstring(response.text)
my_news= []
items = dom.xpath("(//table[@class='stories-set__items'])[3]//td[@class='stories-set__item']")
for item in items:
    new= {}
    name = item.xpath("(.//a[contains(@class, 'link link_theme_black')])[1]/text()")[0]
    source_name= item.xpath("(.//div[contains(@class, 'story__date')])[1]/text()")[0][0: -6]
    source_date =  item.xpath("(.//div[contains(@class, 'story__date')])[1]/text()")[0][-5:]
    d = datetime.date.today()

    source_date = datetime.datetime(d.year, d.month, d.day, int(source_date[0:1]), int(source_date[3:4]), 0)
    link = item.xpath("(.//a[contains(@class, 'link link_theme_black')])[1]/@href")[0] 

    new['name'] = name
    new['source_name'] = source_name
    new['source_date'] = source_date
    new['link'] = link

    my_news.append(new)

# %%
main_link = 'https://lenta.ru'
response = requests.get(main_link,
                            headers=header)
dom = html.fromstring(response.text)

lenta_news= []
items = dom.xpath("(//section[@class='row b-top7-for-main js-top-seven'])[1]//div[@class='item']|//div[@class='first-item']")
for item in items:
    new= {}
    name = item.xpath(".//a[1]/text()")[0] 
    name = name.replace(u'\xa0', u' ')
    source_name= 'lenta.ru' 
    source_date = item.xpath(".//a[1]/time[1]/text()")[0]
    d = datetime.date.today()

    source_date = datetime.datetime(d.year, d.month, d.day, int(source_date[0:1]), int(source_date[3:4]), 0)
    link = main_link + item.xpath(".//a[1]/@href")[0] 

    new['name'] = name
    new['source_name'] = source_name
    new['source_date'] = source_date
    new['link'] = link

    my_news.append(new)

# %%
main_link = 'https://news.mail.ru/?from=menu'
response = requests.get(main_link,
                            headers=header)
dom = html.fromstring(response.text)

mail_news= []
items1 = dom.xpath("(//div[@class='cols__inner'])[5]")[0]
items = items1.xpath(".//li[@class='list__item']|.//div[@class='newsitem newsitem_height_fixed js-ago-wrapper']")

for item in items:
    new= {}
    name = item.xpath(".//a[1]/span/text()")[0] 
    link = item.xpath(".//a[1]/@href")[0] 
    source_name= 'lenta.ru'
    response_mail = requests.get(link,
                            headers=header)
    dom_mail = html.fromstring(response_mail.text)
    d = dom_mail.xpath("(//div[@class='breadcrumbs breadcrumbs_article js-ago-wrapper'])[1]//span[@class='note__text breadcrumbs__text js-ago']/@datetime")[0]
    source_name = dom_mail.xpath("//a[contains(@class, 'breadcrumbs__link')]/span/text()")[0]
    source_date = datetime.datetime(int(d[0:4]), int(d[5:7]), int(d[8:10]), int(d[11:13]),int(d[14:16]), int(d[17:19]))

    

    new['name'] = name
    new['source_name'] = source_name
    new['source_date'] = source_date
    new['link'] = link
    my_news.append(new)

pprint(my_news)
# Out:
# [{'link': 'https://lenta.ru/news/2020/09/14/theend/',
#   'name': 'В Сочи завершились переговоры Путина и Лукашенко',
#   'source_date': datetime.datetime(2020, 9, 14, 1, 0),
#   'source_name': 'lenta.ru'},
#  {'link': 'https://lenta.ru/news/2020/09/14/pashaefff/',
#   'name': 'Пашаев высказался о своей вине в приговоре Ефремову',
#   'source_date': datetime.datetime(2020, 9, 14, 2, 0),
#   'source_name': 'lenta.ru'},
#  {'link': 'https://lenta.ru/news/2020/09/14/backin2007/',
#   'name': 'Путин отменил указ Медведева',
#   'source_date': datetime.datetime(2020, 9, 14, 1, 5),
#   'source_name': 'lenta.ru'},
#  {'link': 'https://lenta.ru/news/2020/09/14/obokrali/',
#   'name': 'Российских туристов обокрали в Турции по новой схеме',
#   'source_date': datetime.datetime(2020, 9, 14, 1, 5),
#   'source_name': 'lenta.ru'},
#  {'link': 'https://lenta.ru/news/2020/09/14/mavz/',
#   'name': 'Мавзолей отказались переделывать из-за угроз',
#   'source_date': datetime.datetime(2020, 9, 14, 1, 5),
#   'source_name': 'lenta.ru'},
#  {'link': 'https://lenta.ru/news/2020/09/14/uvolnenia/',
#   'name': 'Великобритании пообещали волну увольнений',
#   'source_date': datetime.datetime(2020, 9, 14, 1, 5),
#   'source_name': 'lenta.ru'},
#  {'link': 'https://lenta.ru/news/2020/09/14/kaznit/',
#   'name': 'Трамп предложил ввести смертную казнь за убийство полицейских',
#   'source_date': datetime.datetime(2020, 9, 14, 1, 4),
#   'source_name': 'lenta.ru'},
#  {'link': 'https://lenta.ruhttps://moslenta.ru/news/chinovnica-moskovskoi-upravy-izbila-chinovnika-drugoi-raionnoi-upravy-14-09-2020.htm/?utm_source=from_lenta',
#   'name': 'Чиновница московской управы избила чиновника другой управы ',
#   'source_date': datetime.datetime(2020, 9, 14, 1, 4),
#   'source_name': 'lenta.ru'},
#  {'link': 'https://lenta.ru/news/2020/09/14/ns2/',
#   'name': 'Оператор «Северного потока-2» объяснился в суде',
#   'source_date': datetime.datetime(2020, 9, 14, 1, 3),
#   'source_name': 'lenta.ru'},
#  {'link': 'https://lenta.ru/news/2020/09/14/vosstanovili/',
#   'name': 'В России восстановили танк Т-80 с суперпушкой',
#   'source_date': datetime.datetime(2020, 9, 14, 1, 2),
#   'source_name': 'lenta.ru'},
#  {'link': 'https://news.mail.ru/society/43359575/',
#   'name': 'Мурашко: на регистрации в России находятся пять вакцин от COVID-19',
#   'source_date': datetime.datetime(2020, 9, 14, 18, 11, 13),
#   'source_name': 'РИА Новости'},
#  {'link': 'https://news.mail.ru/society/43360737/',
#   'name': 'Британец выращивает гигантские овощи для хосписа',
#   'source_date': datetime.datetime(2020, 9, 14, 18, 5, 27),
#   'source_name': 'Новости Mail.ru'},
#  {'link': 'https://news.mail.ru/society/43360023/',
#   'name': 'Размер материнского капитала вырастет в 2021 году',
#   'source_date': datetime.datetime(2020, 9, 14, 17, 52, 30),
#   'source_name': 'Life.ru'},
#  {'link': 'https://news.mail.ru/society/43360009/',
#   'name': 'Экстремалы из Приморья прошли по канату во время тайфуна (видео)',
#   'source_date': datetime.datetime(2020, 9, 14, 17, 26, 13),
#   'source_name': 'Погода Mail.ru'}]
